# %%
# import pandas package for data analysis, numpy for working numerical values in data structures and matplotlib for charting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# charting display in jupyter
# %matplotlib inline

# charting colors for display in jupyter
plt.style.use("ggplot")

# chart formatting sizes for figure and fonts
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams["font.size"] = 10

# %%
pwd
# Out:
# 'C:\\Users\\Legion\\MyPython\\updated'

# %%
# importing USDCHF dataset in csv format into Python
usdchf = pd.read_csv("C:/Users/Legion/MyPython/updated/usdchf_2.csv")

# %%
usdchf
# Out:
#              Date   Time  Open Price  Highest Price  Lowest Price  \
# 0      2020.05.18   7:08     0.97138        0.97142       0.97137
# 1      2020.05.18   7:09     0.97139        0.97142       0.97139
# 2      2020.05.18   7:10     0.97139        0.97142       0.97139
# 3      2020.05.18   7:11     0.97142        0.97143       0.97142
# 4      2020.05.18   7:12     0.97142        0.97145       0.97142
# ...           ...    ...         ...            ...           ...
# 45752  2023.05.31  16:13     0.91061        0.91062       0.91045
# 45753  2023.05.31  16:14     0.91045        0.91067       0.91038
# 45754  2023.05.31  16:15     0.91053        0.91062       0.91046
# 45755  2023.05.31  16:16     0.91057        0.91060       0.91043
# 45756  2023.05.31  16:17     0.91048        0.91052       0.91047
#
#        Closing Price  Volume Traded
# 0            0.97140             18
# 1            0.97139             15
# 2            0.97142              7
# ...

# %%
usdchf.shape
# Out:
# (45757, 7)

# %%
# checking the data type for the elements in the table columns, especially the Date Time columns
usdchf.dtypes
# Out:
# Date              object
# Time              object
# Open Price       float64
# Highest Price    float64
# Lowest Price     float64
# Closing Price    float64
# Volume Traded      int64
# dtype: object

# %%
# identifying missing data by creating a new table under the variable name of null_usdchf
null_usdchf = pd.DataFrame(usdchf.isnull().sum(), columns = ["Count of Nulls"])
null_usdchf.index.name = "Column"
null_usdchf.sort_values(["Count of Nulls"], ascending = False)
# Out:
#                Count of Nulls
# Column
# Open Price                  8
# Highest Price               7
# Lowest Price                6
# Closing Price               2
# Date                        0
# Time                        0
# Volume Traded               0

# %%
# understanding the data to observe the available data sampling
usdchf[["Open Price","Highest Price","Lowest Price","Closing Price"]].describe()
# Out:
#          Open Price  Highest Price  Lowest Price  Closing Price
# count  45749.000000   45750.000000  45751.000000   45755.000000
# mean       0.931580       0.931642      0.931521       0.931586
# std        0.025589       0.025590      0.025590       0.025592
# min        0.894050       0.894150      0.894020       0.894030
# 25%        0.917960       0.918020      0.917900       0.917965
# 50%        0.922970       0.923030      0.922910       0.922980
# 75%        0.965160       0.965210      0.965090       0.965160
# max        0.975420       0.976040      0.974550       0.975420

# %%
# understanding the data to observe the available data sampling - checking the median
usdchf[["Open Price","Highest Price","Lowest Price","Closing Price"]].median()
# Out:
# Open Price       0.92297
# Highest Price    0.92303
# Lowest Price     0.92291
# Closing Price    0.92298
# dtype: float64

# %%
# understanding the data to observe the available data sampling - checking the mode

usdchf_check = usdchf[["Open Price","Highest Price","Lowest Price","Closing Price"]]
print(usdchf_check)

usdchf_check_mode = usdchf_check.mode()
print(usdchf_check_mode)
# Out:
#        Open Price  Highest Price  Lowest Price  Closing Price
# 0         0.97138        0.97142       0.97137        0.97140
# 1         0.97139        0.97142       0.97139        0.97139
# 2         0.97139        0.97142       0.97139        0.97142
# 3         0.97142        0.97143       0.97142        0.97142
# 4         0.97142        0.97145       0.97142        0.97144
# ...           ...            ...           ...            ...
# 45752     0.91061        0.91062       0.91045        0.91046
# 45753     0.91045        0.91067       0.91038        0.91052
# 45754     0.91053        0.91062       0.91046        0.91056
# 45755     0.91057        0.91060       0.91043        0.91049
# 45756     0.91048        0.91052       0.91047        0.91052
#
# [45757 rows x 4 columns]
#    Open Price  Highest Price  Lowest Price  Closing Price
# 0     0.92415         0.9206       0.92406        0.92407

# %%
# to see from the list the missing value for Open Price
usdchf[usdchf["Open Price"].isna()]
# Out:
#            Date   Time  Open Price  Highest Price  Lowest Price  \
# 22   2020.05.18   7:30         NaN        0.97150       0.97147
# 102  2020.05.18   8:50         NaN        0.97188       0.97176
# 219  2020.05.18  10:47         NaN        0.97231       0.97223
# 291  2020.05.18  11:59         NaN        0.97244       0.97222
# 426  2020.05.18  14:14         NaN        0.97245       0.97228
# 517  2020.05.18  15:45         NaN        0.97089       0.97068
# 679  2020.05.18  18:27         NaN        0.96898       0.96822
# 796  2020.05.18  20:24         NaN        0.97495       0.97455
#
#      Closing Price  Volume Traded
# 22         0.97147             17
# 102        0.97177             30
# 219        0.97225             77
# 291        0.97243             52
# 426        0.97245             92
# 517        0.97088             81
# 679        0.96883            243
# 796        0.97492             91

# %%
# to see from the list missing values for Highest Price
usdchf[usdchf["Highest Price"].isna()]
# Out:
#             Date   Time  Open Price  Highest Price  Lowest Price  \
# 1398  2020.05.19   6:34     0.97212            NaN       0.97212
# 1550  2020.05.19   9:07     0.97195            NaN       0.97188
# 1560  2020.05.19   9:17     0.97184            NaN       0.97175
# 1614  2020.05.19  10:11     0.97233            NaN       0.97226
# 2332  2020.05.19  22:09     0.97103            NaN       0.97096
# 2371  2020.05.19  22:48     0.97102            NaN       0.97094
# 2560  2020.05.20   2:13     0.97110            NaN       0.97101
#
#       Closing Price  Volume Traded
# 1398        0.97214             40
# 1550        0.97194             62
# 1560        0.97189             72
# 1614        0.97226             85
# 2332        0.97117             74
# 2371        0.97099             58
# 2560        0.97114             41

# %%
# to see from the list missing values for Lowest Price
usdchf[usdchf["Lowest Price"].isna()]
# Out:
#             Date   Time  Open Price  Highest Price  Lowest Price  \
# 1562  2020.05.19   9:19     0.97177        0.97192           NaN
# 2558  2020.05.20   2:11     0.97115        0.97117           NaN
# 3357  2020.05.20  15:31     0.96535        0.96540           NaN
# 3987  2020.05.21   2:14     0.96491        0.96491           NaN
# 4356  2020.05.21   8:27     0.96618        0.96620           NaN
# 5085  2020.05.21  20:36     0.96986        0.96993           NaN
#
#       Closing Price  Volume Traded
# 1562        0.97187             82
# 2558        0.97108             14
# 3357        0.96538             47
# 3987        0.96491              9
# 4356        0.96620             10
# 5085        0.96990             70

# %%
# to see from the list missing values for Closing Price
usdchf[usdchf["Closing Price"].isna()]
# Out:
#             Date   Time  Open Price  Highest Price  Lowest Price  \
# 4759  2020.05.21  15:10     0.96609        0.96614       0.96597
# 5129  2020.05.21  21:20     0.97042        0.97044       0.97038
#
#       Closing Price  Volume Traded
# 4759            NaN             75
# 5129            NaN             30

# %%
# drop the missing value in Closing Price column because it has only 2 missing values, therefore the deletion of the data
# will not significantly impact the data pattern
usdchf.dropna(subset = ["Closing Price"], inplace = True)

# %%
# check if Closing Price still has missing value or not
usdchf[["Closing Price"]].isnull().sum()
# Out:
# Closing Price    0
# dtype: int64

# %%
# checking row value for a specified column at defined table index location
usdchf[["Open Price"]].iloc[4759]
# Out:
# Open Price    0.96598
# Name: 4760, dtype: float64

# %%
# fill the missing data with mode value for each Open Price, Highest Price, Lowest Price

usdchf.fillna(value = {"Open Price": 0.92415, "Highest Price" : 0.9206, "Lowest Price" : 0.92406}, inplace=True)

# %%
# checking the success of getting the empty data replace with a mode value for the corresponding column
usdchf[["Closing Price","Open Price","Highest Price","Lowest Price"]].isnull().sum()
# Out:
# Closing Price    0
# Open Price       0
# Highest Price    0
# Lowest Price     0
# dtype: int64

# %%
usdchf
# Out:
#              Date   Time  Open Price  Highest Price  Lowest Price  \
# 0      2020.05.18   7:08     0.97138        0.97142       0.97137
# 1      2020.05.18   7:09     0.97139        0.97142       0.97139
# 2      2020.05.18   7:10     0.97139        0.97142       0.97139
# 3      2020.05.18   7:11     0.97142        0.97143       0.97142
# 4      2020.05.18   7:12     0.97142        0.97145       0.97142
# ...           ...    ...         ...            ...           ...
# 45752  2023.05.31  16:13     0.91061        0.91062       0.91045
# 45753  2023.05.31  16:14     0.91045        0.91067       0.91038
# 45754  2023.05.31  16:15     0.91053        0.91062       0.91046
# 45755  2023.05.31  16:16     0.91057        0.91060       0.91043
# 45756  2023.05.31  16:17     0.91048        0.91052       0.91047
#
#        Closing Price  Volume Traded
# 0            0.97140             18
# 1            0.97139             15
# 2            0.97142              7
# ...

# %%
# when we remove TWO empty data in Closing Price, the entire data in row indexed at 4759 and 5129 are also removed
# hence, the row indexing will skip the number 4759 and 5129. Meaning the row indexing is 4758 followed by 4760. Similar to
# row indexed at 5129.
# to reset the row indexing number, below is the syntax
usdchf.reset_index(inplace=True)

# %%
# to see the result of index row location resetting
usdchf
# Out:
#        index        Date   Time  Open Price  Highest Price  Lowest Price  \
# 0          0  2020.05.18   7:08     0.97138        0.97142       0.97137
# 1          1  2020.05.18   7:09     0.97139        0.97142       0.97139
# 2          2  2020.05.18   7:10     0.97139        0.97142       0.97139
# 3          3  2020.05.18   7:11     0.97142        0.97143       0.97142
# 4          4  2020.05.18   7:12     0.97142        0.97145       0.97142
# ...      ...         ...    ...         ...            ...           ...
# 45750  45752  2023.05.31  16:13     0.91061        0.91062       0.91045
# 45751  45753  2023.05.31  16:14     0.91045        0.91067       0.91038
# 45752  45754  2023.05.31  16:15     0.91053        0.91062       0.91046
# 45753  45755  2023.05.31  16:16     0.91057        0.91060       0.91043
# 45754  45756  2023.05.31  16:17     0.91048        0.91052       0.91047
#
#        Closing Price  Volume Traded
# 0            0.97140             18
# ...

# %%
# you can see the above how the Data Frame row indexing are done
# outputting the value for Open Price at row indexing of 45750
usdchf[["Open Price"]].iloc[45750]
# Out:
# Open Price    0.91061
# Name: 45750, dtype: float64

# %%
# creating new table with two columns Date and Time
new_datetime = usdchf[["Date","Time"]]

# %%
new_datetime
# Out:
#              Date   Time
# 0      2020.05.18   7:08
# 1      2020.05.18   7:09
# 2      2020.05.18   7:10
# 3      2020.05.18   7:11
# 4      2020.05.18   7:12
# ...           ...    ...
# 45750  2023.05.31  16:13
# 45751  2023.05.31  16:14
# 45752  2023.05.31  16:15
# 45753  2023.05.31  16:16
# 45754  2023.05.31  16:17
#
# [45755 rows x 2 columns]

# %%
new_datetime.dtypes
# Out:
# Date    object
# Time    object
# dtype: object

# %%
# combining Date column and Time column in new_datetime table into one new column and set it as TimeStamp object
new_datetime["DateTime"] = pd.to_datetime(new_datetime["Date"] + " " + new_datetime["Time"])
# Out:
# C:\Users\Legion\AppData\Local\Temp\ipykernel_26584\177569246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_datetime["DateTime"] = pd.to_datetime(new_datetime["Date"] + " " + new_datetime["Time"])

# %%
new_datetime
# Out:
#              Date   Time            DateTime
# 0      2020.05.18   7:08 2020-05-18 07:08:00
# 1      2020.05.18   7:09 2020-05-18 07:09:00
# 2      2020.05.18   7:10 2020-05-18 07:10:00
# 3      2020.05.18   7:11 2020-05-18 07:11:00
# 4      2020.05.18   7:12 2020-05-18 07:12:00
# ...           ...    ...                 ...
# 45750  2023.05.31  16:13 2023-05-31 16:13:00
# 45751  2023.05.31  16:14 2023-05-31 16:14:00
# 45752  2023.05.31  16:15 2023-05-31 16:15:00
# 45753  2023.05.31  16:16 2023-05-31 16:16:00
# 45754  2023.05.31  16:17 2023-05-31 16:17:00
#
# [45755 rows x 3 columns]

# %%
new_datetime.dtypes
# Out:
# Date                object
# Time                object
# DateTime    datetime64[ns]
# dtype: object

# %%
# creating new table under new variable new_datetime2 with single column of TimeStamp object
new_datetime2 = new_datetime[["DateTime"]]

# %%
new_datetime2
# Out:
#                  DateTime
# 0     2020-05-18 07:08:00
# 1     2020-05-18 07:09:00
# 2     2020-05-18 07:10:00
# 3     2020-05-18 07:11:00
# 4     2020-05-18 07:12:00
# ...                   ...
# 45750 2023-05-31 16:13:00
# 45751 2023-05-31 16:14:00
# 45752 2023-05-31 16:15:00
# 45753 2023-05-31 16:16:00
# 45754 2023-05-31 16:17:00
#
# [45755 rows x 1 columns]

# %%
new_datetime2.dtypes
# Out:
# DateTime    datetime64[ns]
# dtype: object

# %%
# inserting new column with TimeStamp object at column with index 2 location into existing usdchf table
usdchf.insert(2, "Date and Time", new_datetime2["DateTime"], True)

# %%
usdchf.head(3)
# Out:
#    index        Date       Date and Time  Time  Open Price  Highest Price  \
# 0      0  2020.05.18 2020-05-18 07:08:00  7:08     0.97138        0.97142
# 1      1  2020.05.18 2020-05-18 07:09:00  7:09     0.97139        0.97142
# 2      2  2020.05.18 2020-05-18 07:10:00  7:10     0.97139        0.97142
#
#    Lowest Price  Closing Price  Volume Traded
# 0       0.97137        0.97140             18
# 1       0.97139        0.97139             15
# 2       0.97139        0.97142              7

# %%
usdchf.shape
# Out:
# (45755, 9)

# %%
# create new list from usdchf existing column of Open Price
num1 = list(usdchf["Open Price"])

# create new list from usdchf existing column of Closing Price
num2 = list(usdchf["Closing Price"])

# %%
# # testing the above code line of creating list from one of usdchf column
# print(num1)
# print(len(num1))
# print(type(num1))

# %%
# testing the above code line of creating list from one of usdchf column
# print(num2)
# print(len(num2))
# print(type(num2))

# %%
# create a new dictionary from two list from num1 and num2 
# the value for the key is a list where each list element is absolute value of elements num1 substracting elements num2
newcol = {"Candlestick Body": []}
for i in range(len(num1)):
    newcol["Candlestick Body"].append(abs(num1[i]-num2[i]))

# %%
print(newcol)
# Out:
# {'Candlestick Body': [2.0000000000020002e-05, 0.0, 2.999999999997449e-05, 0.0, 2.0000000000020002e-05, 0.0, 0.0, 4.999999999999449e-05, 9.99999999995449e-06, 7.00000000000145e-05, 9.99999999995449e-06, 2.999999999997449e-05, 0.0, 0.0, 1.0000000000065512e-05, 0.0, 0.0, 8.000000000008001e-05, 3.0000000000085514e-05, 0.0, 2.0000000000020002e-05, 0.0, 0.04731999999999992, 0.0, 1.0000000000065512e-05, 8.999999999992347e-05, 2.999999999997449e-05, 1.0000000000065512e-05, 3.999999999992898e-05, 2.999999999997449e-05, 1.0000000000065512e-05, 0.0, 0.0, 2.0000000000020002e-05, 9.99999999995449e-06, 0.0001500000000000945, 7.999999999996898e-05, 1.999999999990898e-05, 9.99999999995449e-06, 9.99999999995449e-06, 2.999999999997449e-05, 1.0000000000065512e-05, 2.999999999997449e-05, 1.0000000000065512e-05, 1.0000000000065512e-05, 1.0000000000065512e-05, 9.99999999995449e-06, 2.0000000000020002e-05, 1.0000000000065512e-05, 0.0, 1.0000000000065512e-05, 6.999999999990347e-05, 4.999999999999449e-05, 4.
# ...

# %%
print(len(newcol["Candlestick Body"]))
# Out:
# 45755

# %%
# create a new table from the newly created dictionary "newcol"
df1 = pd.DataFrame(newcol)

# %%
df1.head(5)
# Out:
#    Candlestick Body
# 0           0.00002
# 1           0.00000
# 2           0.00003
# 3           0.00000
# 4           0.00002

# %%
# inserting a new column "Candlestick Body" to existing usdchf table at column with index 9 location of usdchf table
usdchf.insert(9,"Candlestick Body",df1["Candlestick Body"], True)

# %%
usdchf
# Out:
#        index        Date       Date and Time   Time  Open Price  \
# 0          0  2020.05.18 2020-05-18 07:08:00   7:08     0.97138
# 1          1  2020.05.18 2020-05-18 07:09:00   7:09     0.97139
# 2          2  2020.05.18 2020-05-18 07:10:00   7:10     0.97139
# 3          3  2020.05.18 2020-05-18 07:11:00   7:11     0.97142
# 4          4  2020.05.18 2020-05-18 07:12:00   7:12     0.97142
# ...      ...         ...                 ...    ...         ...
# 45750  45752  2023.05.31 2023-05-31 16:13:00  16:13     0.91061
# 45751  45753  2023.05.31 2023-05-31 16:14:00  16:14     0.91045
# 45752  45754  2023.05.31 2023-05-31 16:15:00  16:15     0.91053
# 45753  45755  2023.05.31 2023-05-31 16:16:00  16:16     0.91057
# 45754  45756  2023.05.31 2023-05-31 16:17:00  16:17     0.91048
#
#        Highest Price  Lowest Price  Closing Price  Volume Traded  \
# 0            0.97142       0.97137        0.97140             18
# ...

# %%
# create a function to construct a dictionary from existing list
def create_diction(list1,list2,list3):
    trio_price = {}
    trio_price["Open_Price"] = list1
    trio_price["High/Low_Price"] = list2
    trio_price["Close_Price"] = list3
    return trio_price

# %%
#  create three new separate list from column Open Price, Highest Price and Closing Price of usdchf table
num3 = list(usdchf["Open Price"])
num4 = list(usdchf["Highest Price"])
num5 = list(usdchf["Closing Price"])

# %%
shadow_price = create_diction(num3,num4,num5)

# %%
# # checking the above code line
# print(type(shadow_price))
# print(shadow_price)
# print(len(shadow_price))
# print(len(shadow_price["Open_Price"]))
# for i in shadow_price:
#     print(i)

# %%
# # check to ensure shadow_price key has similar number of value elements
# print(len(shadow_price["Close_Price"]))
# print(len(shadow_price["High/Low_Price"]))

# %%
# create a new list where each element is the price difference between Highest Price and Open/Close Price from usdchf table
pricediff1 = []
for i in range(len(shadow_price["Open_Price"])):
    if shadow_price["Open_Price"][i] < shadow_price["Close_Price"][i]:
        num1 = abs(shadow_price["High/Low_Price"][i] - shadow_price["Close_Price"][i])
    else:
        num1 = abs(shadow_price["High/Low_Price"][i] - shadow_price["Open_Price"][i])
    pricediff1.append(num1)

# %%
print(pricediff1)
print(type(pricediff1))
print(len(pricediff1))

# %%
# convert this newly created list as a new column in usdchf table - add as very last column
usdchf["Upper Shadow Price"] = pricediff1

# %%
usdchf
# Out:
#        index        Date       Date and Time   Time  Open Price  \
# 0          0  2020.05.18 2020-05-18 07:08:00   7:08     0.97138
# 1          1  2020.05.18 2020-05-18 07:09:00   7:09     0.97139
# 2          2  2020.05.18 2020-05-18 07:10:00   7:10     0.97139
# 3          3  2020.05.18 2020-05-18 07:11:00   7:11     0.97142
# 4          4  2020.05.18 2020-05-18 07:12:00   7:12     0.97142
# ...      ...         ...                 ...    ...         ...
# 45750  45752  2023.05.31 2023-05-31 16:13:00  16:13     0.91061
# 45751  45753  2023.05.31 2023-05-31 16:14:00  16:14     0.91045
# 45752  45754  2023.05.31 2023-05-31 16:15:00  16:15     0.91053
# 45753  45755  2023.05.31 2023-05-31 16:16:00  16:16     0.91057
# 45754  45756  2023.05.31 2023-05-31 16:17:00  16:17     0.91048
#
#        Highest Price  Lowest Price  Closing Price  Volume Traded  \
# 0            0.97142       0.97137        0.97140             18
# ...

# %%
# # check to ensure list num3 and num5 are still per original, no latest value defined for these lists
# print(num3[-1])
# print(num3[0])
# print(num5[0])
# print(num5[-1])

# %%
# create new list from column Lowest Price of usdchf table
num6 = list(usdchf["Lowest Price"])

# %%
# print(type(num6))
# print(num6[0])
# print(num6[-1])
# print(num6)
# print(len(num6))

# %%
# create a new dictionary from a given set of list
shadow_price2 = create_diction(num3,num6,num5)

# %%
# # checking the above code line
# print(type(shadow_price2))
# print(len(shadow_price2))
# for i in shadow_price2:
#     print(i)
# print(shadow_price2)

# %%
# # check to ensure shadow_price2 key has similar number of value elements
# print(len(shadow_price2["Open_Price"]))
# print(len(shadow_price2["Close_Price"]))
# print(len(shadow_price2["High/Low_Price"]))

# %%
# create a new list where each element is the price difference between Highest Price and Open/Close Price from usdchf table
pricediff2 = []
for i in range(len(shadow_price2["Open_Price"])):
    if shadow_price2["Open_Price"][i] > shadow_price2["Close_Price"][i]:
        num1 = abs(shadow_price2["Close_Price"][i] - shadow_price2["High/Low_Price"][i])
    else:
        num1 = abs(shadow_price2["Open_Price"][i] - shadow_price2["High/Low_Price"][i])
    pricediff2.append(num1)

# %%
print(pricediff2)
print(type(pricediff2))
print(len(pricediff2))

# %%
# convert this newly created list as a new column in usdchf table
usdchf["Lower Shadow Price"] = pricediff2

# %%
usdchf
# Out:
#        index        Date       Date and Time   Time  Open Price  \
# 0          0  2020.05.18 2020-05-18 07:08:00   7:08     0.97138
# 1          1  2020.05.18 2020-05-18 07:09:00   7:09     0.97139
# 2          2  2020.05.18 2020-05-18 07:10:00   7:10     0.97139
# 3          3  2020.05.18 2020-05-18 07:11:00   7:11     0.97142
# 4          4  2020.05.18 2020-05-18 07:12:00   7:12     0.97142
# ...      ...         ...                 ...    ...         ...
# 45750  45752  2023.05.31 2023-05-31 16:13:00  16:13     0.91061
# 45751  45753  2023.05.31 2023-05-31 16:14:00  16:14     0.91045
# 45752  45754  2023.05.31 2023-05-31 16:15:00  16:15     0.91053
# 45753  45755  2023.05.31 2023-05-31 16:16:00  16:16     0.91057
# 45754  45756  2023.05.31 2023-05-31 16:17:00  16:17     0.91048
#
#        Highest Price  Lowest Price  Closing Price  Volume Traded  \
# 0            0.97142       0.97137        0.97140             18
# ...

# %%
usdchf[["Volume Traded","Candlestick Body","Upper Shadow Price","Lower Shadow Price"]].describe()
# Out:
#        Volume Traded  Candlestick Body  Upper Shadow Price  Lower Shadow Price
# count   45755.000000      45755.000000        45755.000000        45755.000000
# mean       54.415364          0.000080            0.000033            0.000040
# std        39.459529          0.000636            0.000632            0.000808
# min         1.000000          0.000000            0.000000            0.000000
# 25%        24.000000          0.000020            0.000000            0.000000
# 50%        46.000000          0.000050            0.000010            0.000010
# 75%        76.000000          0.000100            0.000030            0.000030
# max       379.000000          0.050770            0.051730            0.050400

# %%
# create a function to change the price difference small value by 1,000,000 times for ease of charting and save it as list
def create_list(list1):
    n = len(list1)
    new_list = []
    j = 0
    while j < n:
        new_list.append((list1[j])*1000000)
        j += 1
    return new_list

# %%
# create a new list from column Candlestick Body of usdchf table
num7 = list(usdchf["Candlestick Body"])

# create a new list from column Upper Shadow Price of usdchf table
num8 = list(usdchf["Upper Shadow Price"])

# create a new list from column Lower Shadow Price of usdchf table
num9 = list(usdchf["Lower Shadow Price"])

# %%
# create a set of new list that change the less than unity price difference by 1,000,000 for ease of charting
new_Candlestick = create_list(num7)
new_UpperShadow = create_list(num8)
new_LowerShadow = create_list(num9)

# %%
# adding new columns into usdchf table
usdchf["Candlestick Body '000,000'"] = new_Candlestick
usdchf["Upper Shadow Price '000,000'"] = new_UpperShadow
usdchf["Lower Shadow Price '000,000'"] = new_LowerShadow

# %%
usdchf
# Out:
#        index        Date       Date and Time   Time  Open Price  \
# 0          0  2020.05.18 2020-05-18 07:08:00   7:08     0.97138
# 1          1  2020.05.18 2020-05-18 07:09:00   7:09     0.97139
# 2          2  2020.05.18 2020-05-18 07:10:00   7:10     0.97139
# 3          3  2020.05.18 2020-05-18 07:11:00   7:11     0.97142
# 4          4  2020.05.18 2020-05-18 07:12:00   7:12     0.97142
# ...      ...         ...                 ...    ...         ...
# 45750  45752  2023.05.31 2023-05-31 16:13:00  16:13     0.91061
# 45751  45753  2023.05.31 2023-05-31 16:14:00  16:14     0.91045
# 45752  45754  2023.05.31 2023-05-31 16:15:00  16:15     0.91053
# 45753  45755  2023.05.31 2023-05-31 16:16:00  16:16     0.91057
# 45754  45756  2023.05.31 2023-05-31 16:17:00  16:17     0.91048
#
#        Highest Price  Lowest Price  Closing Price  Volume Traded  \
# 0            0.97142       0.97137        0.97140             18
# ...

# %%
usdchf[["Volume Traded","Candlestick Body '000,000'","Upper Shadow Price '000,000'","Lower Shadow Price '000,000'"]].describe()
# Out:
#        Volume Traded  Candlestick Body '000,000'  \
# count   45755.000000                45755.000000
# mean       54.415364                   79.953885
# std        39.459529                  636.389705
# min         1.000000                    0.000000
# 25%        24.000000                   20.000000
# 50%        46.000000                   50.000000
# 75%        76.000000                  100.000000
# max       379.000000                50770.000000
#
#        Upper Shadow Price '000,000'  Lower Shadow Price '000,000'
# count                  45755.000000                  45755.000000
# mean                      32.748552                     39.777729
# std                      632.364037                    807.717616
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                       10.000000                     10.000000
# ...

# %%
usdchf[["Volume Traded","Candlestick Body '000,000'","Upper Shadow Price '000,000'","Lower Shadow Price '000,000'"]].median()
# Out:
# Volume Traded                   46.0
# Candlestick Body '000,000'      50.0
# Upper Shadow Price '000,000'    10.0
# Lower Shadow Price '000,000'    10.0
# dtype: float64

# %%
usdchfmode = usdchf[["Volume Traded","Candlestick Body '000,000'","Upper Shadow Price '000,000'","Lower Shadow Price '000,000'"]]
usdchfmode_check = usdchfmode.mode()
print(usdchfmode_check)
# Out:
#    Volume Traded  Candlestick Body '000,000'  Upper Shadow Price '000,000'  \
# 0             15                         0.0                           0.0
#
#    Lower Shadow Price '000,000'
# 0                           0.0

# %%
# # set the chart figure size
# plt.figure(figsize = (100,7))

# # create the plot
# plt.plot_date(usdchf["Date and Time"], usdchf["Volume Traded"], "-", label = usdchf)

# # formatting the chart presentation
# plt.xlabel("Date and Time")
# plt.ylabel("Volume Traded")
# plt.title("Volume Traded vs 1 minute Timeframe")
# # plt.legend()
# # show the plot
# plt.show()

# %%
# set the chart figure size
plt.figure(figsize = (10,7))

# create the plot
plt.plot(usdchf["Date and Time"], usdchf["Volume Traded"])

# formatting the chart presentation
plt.xlabel("Date and Time")
plt.ylabel("Volume Traded")
plt.title("Volume Traded vs 1 minute Timeframe")

plt.show()

# %%
# set the chart figure size
plt.figure(figsize = (10,7))

# create the plot
plt.plot(usdchf["Date and Time"], usdchf["Open Price"])

# formatting the chart presentation
plt.xlabel("Date and Time")
plt.ylabel("Open Price in USD")
plt.title("Open Price vs 1 minute Timeframe")

plt.show()

# %%
# set the chart figure size
plt.figure(figsize = (10,7))

# create the plot
plt.plot(usdchf["Date and Time"], usdchf["Closing Price"])

# formatting the chart presentation
plt.xlabel("Date and Time")
plt.ylabel("Closing Price in USD")
plt.title("Closing Price vs 1 minute Timeframe")

plt.show()

# %%
# set the chart figure size
plt.figure(figsize = (10,7))

# create the plot
plt.plot(usdchf["Date and Time"], usdchf["Candlestick Body '000,000'"])

# formatting the chart presentation
plt.xlabel("Date and Time")
plt.ylabel("Candlestick Body '000,000'")
plt.title("Candlestick Body vs 1 minute Timeframe")

plt.show()

# %%
# Create a new figure and set its size
plt.figure(figsize=(10,6))

# Plot Closing Price
plt.plot(usdchf['Date and Time'], usdchf["Closing Price"], label='Closing Price')

# Plot Open Price
plt.plot(usdchf['Date and Time'], usdchf['Open Price'], label='Open Price')

# Add labels, legend, and title
plt.xlabel('DateTime')
plt.ylabel('Value')
plt.title('USDCHF Open Price and Closing Price at 1 Minute Timeframe')
plt.legend()

# Show the plot
plt.show()

# %%
# usdchf.plot(kind="scatter", x="Date and Time",y="Volume Traded",color="maroon",figsize=(200,50),s=150,alpha=0.5)
# plt.rcParams["figure.figsize"] = (5,5)
# plt.rcParams["font.size"] = 100

# %%
# usdchf[["Date and Time","Volume Traded"]].describe()

# %%
trioprice = {
    "AA" : [10,8,6,4,2],
    "BB" : [11,15,13,12,11],
    "CC" : [8,2,9,4,6]
}

# %%
print(trioprice)

# %%
print(type(trioprice))
print(type(trioprice["AA"]))
print(type(trioprice["AA"][-1]))
print(len(trioprice["AA"]))
print(len(trioprice["CC"]))

# %%
pricediff = []
for i in range(len(trioprice["AA"])):
    if trioprice["AA"][i] < trioprice["CC"][i]:
        num100 = trioprice["BB"][i] - trioprice["CC"][i]
    else:
        num100 = trioprice["BB"][i] - trioprice["AA"][i]
    pricediff.append(num100)

# %%
pricediff
